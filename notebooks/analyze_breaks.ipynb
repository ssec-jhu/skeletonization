# %%
import cv2
import numpy as np
from scipy.spatial.distance import cdist

# Load binary image (0 = background, 255 = foreground)
binary_image = cv2.imread("/Users/vkluzner/OneDrive/NeuralMorphology/Simulations_16bit_Size3334/output/ex7/evaluation_mean/1-Sample-1-time-100.00_pred_bin.tif", cv2.IMREAD_GRAYSCALE)

# Check the loops
inverted_image = cv2.bitwise_not(binary_image)
num_labels, labels = cv2.connectedComponents(inverted_image)
if num_labels > 2: # there are loops
    # TBD - break the loops
    print("There are loops in the image.")
 
# Label connected components
num_labels, labels = cv2.connectedComponents(binary_image)

# Store pixel coordinates of each component (excluding background label 0)
components = {}
for label in range(1, num_labels):  # Ignore label 0 (background)
    yx_coords = np.column_stack(np.where(labels == label))  # (row, col) -> (y, x)
    components[label] = yx_coords

# Sort components by the number of pixels (in descending order)
sorted_components = dict(
    sorted(components.items(), key=lambda item: len(item[1]), reverse=True)
)

# Print sorted component sizes
for label, pixels in sorted_components.items():
    print(f"Label {label}: {len(pixels)} pixels")
    
# Compute the minimum boundary distance and track pixel pairs
min_distance = np.inf
closest_pair = None  # Store pixel pair (p1, p2)
component_keys = list(sorted_components.keys())
for i in range(len(component_keys)):
    for j in range(i + 1, len(component_keys)):
        # Compute pairwise distances between pixels of component i and j
        dist_matrix = cdist(sorted_components[component_keys[i]], sorted_components[component_keys[j]])
        # Find the minimum distance in this pair
        min_idx = np.unravel_index(np.argmin(dist_matrix), dist_matrix.shape)
        dist_value = dist_matrix[min_idx]
        # Update global minimum distance and pixel pair
        if dist_value < min_distance:
            min_distance = dist_value
            closest_pair = (
                tuple(sorted_components[component_keys[i]][min_idx[0]]),  # Closest pixel in component i
                tuple(sorted_components[component_keys[j]][min_idx[1]])   # Closest pixel in component j
            )

# Print results
print(f"Minimum boundary-to-boundary distance: {min_distance:.2f} pixels")
print(f"Closest pixel pair: {closest_pair[0]} ↔ {closest_pair[1]}")
# Out:
# Label 2: 125612 pixels
# Label 135: 2678 pixels
# Label 32: 2133 pixels
# Label 70: 1134 pixels
# Label 144: 1059 pixels
# Label 196: 643 pixels
# Label 40: 620 pixels
# Label 47: 618 pixels
# Label 192: 566 pixels
# Label 175: 470 pixels
# Label 185: 442 pixels
# Label 69: 400 pixels
# Label 297: 382 pixels
# Label 295: 325 pixels
# Label 155: 320 pixels
# Label 289: 303 pixels
# Label 171: 300 pixels
# Label 266: 295 pixels
# Label 215: 282 pixels
# Label 222: 275 pixels
# Label 156: 263 pixels
# Label 203: 248 pixels
# Label 129: 234 pixels
# Label 191: 233 pixels
# Label 59: 223 pixels
# Label 242: 223 pixels
# Label 62: 221 pixels
# Label 95: 217 pixels
# Label 77: 209 pixels
# Label 283: 209 pixels
# Label 126: 208 pixels
# Label 85: 203 pixels
# Label 5: 196 pixels
# Label 82: 192 pixels
# Label 298: 191 pixels
# Label 201: 185 pixels
# Label 123: 182 pixels
# Label 29: 177 pixels
# Label 270: 171 pixels
# Label 163: 163 pixels
# Label 158: 157 pixels
# Label 149: 155 pixels
# ...
